# %%
import numpy as np
import pandas as pd

# %%
tmp = pd.read_csv("/home/ran/Downloads/breast_cancer.csv")

# %%
tmp
# Out:
#      Disease_status  methylaiton_value
# 0                 2           0.191289
# 1                 1           0.172956
# 2                 0           0.142224
# 3                 2           0.164771
# 4                 2           0.845450
# 5                 0           0.161138
# 6                 2           0.808860
# 7                 2           0.153129
# 8                 2           0.821696
# 9                 2           0.147141
# 10                2           0.895135
# 11                3           0.775475
# 12                2           0.145864
# 13                2           0.825391
# 14                2           0.142033
# 15                2           0.588001
# 16                1           0.764975
# 17                2           0.845454
# 18                0           0.159293
# 19                2           0.144252
# 20                2           0.127210
# 21                2           0.857061
# 22                2           0.579941
# ...

# %%
score = pd.read_csv("/home/ran/Downloads/scores_by_section.csv")

# %%
score
# Out:
#      Section  Score
# 0         12      8
# 1          8      7
# 2          8      7
# 3          3      7
# 4          2      8
# 5          2      4
# 6          2      0
# 7          5      5
# 8          3      7
# 9         10      6
# 10        12      0
# 11        10      7
# 12         9      9
# 13         3      8
# 14         5      4
# 15         9     10
# 16         6      8
# 17        11      9
# 18         3      5
# 19         2      7
# 20         9      9
# 21        11      8
# 22         9      4
# 23         2      7
# 24         9      7
# 25         6      7
# 26        10      7
# 27         7      1
# 28         5      9
# 29         3      0
# ..       ...    ...
# 320        6      7
# 321        9      8
# 322        5      8
# 323       12      3
# 324       10      8
# 325        8      8
# 326        6      9
# 327        5      7
# 328        5      7
# 329        4      7
# 330        5      9
# 331        7      6
# 332       12      6
# ...

# %%
score.groupby("Section")["Score"].mean()
# Out:
# Section
# 1     5.857143
# 2     6.068966
# 3     5.722222
# 4     6.275862
# 5     6.027027
# 6     5.903226
# 7     5.333333
# 8     6.892857
# 9     6.250000
# 10    6.800000
# 11    7.000000
# 12    5.258065
# Name: Score, dtype: float64

# %%
score.groupby("Section").count()
# Out:
#          Score
# Section
# 1           21
# 2           29
# 3           36
# 4           29
# 5           37
# 6           31
# 7           24
# 8           28
# 9           24
# 10          35
# 11          25
# 12          31
